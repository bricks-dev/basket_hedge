# %%
from data import get_all_price

symbols = ['BTC','ETH','XRP','LTC','UNI','LINK','EOS','IOST', 'BCH','BNB','TRX']
data = get_all_price(symbols,'1d')
# Out:
# get price for BTC
# get price for ETH
# get price for XRP
# get price for LTC
# get price for UNI
# get price for LINK
# get price for EOS
# get price for IOST
# get price for BCH
# get price for BNB
# get price for TRX

# %%
from backtest import backtest

backtest(data, ['BTC','ETH'],['XRP','BCH','EOS'], True, True)
# Out:
# long:[BTC,ETH],short:[XRP,BCH,EOS], min:-0.10056780558907968 max:1.5343617205009699(363.83640122584245%), mdd:-0.8286250075366139, sharp:1.906544089362801
# ('long:[BTC,ETH],short:[XRP,BCH,EOS]', 1.906544089362801)

# %%
from comb import find_combinations

find_combinations(data, symbols)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-78139300e173> in <module>
#       1 from comb import find_combinations
#       2
# ----> 3 find_combinations(symbols)
#
# TypeError: find_combinations() missing 1 required positional argument: 'symbols'
